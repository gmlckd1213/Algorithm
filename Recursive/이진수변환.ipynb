# %%
from IPython.display import Image

# %%
Image("이진수변환.png")

# %%
def change(m):
    if m == 1:
        return str(m%2)
    return change(m//2)+str(m%2)
    

def main():
    n = int(input())
    print(change(n))
    
if __name__ == "__main__":
    main()
# Out:
# 19
# 10011
